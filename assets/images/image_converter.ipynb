# %%
from PIL import Image
import os

def convert_all_images_to_webp(directory, quality=80):
    # 변환할 확장자 목록
    valid_extensions = ['.jpg', '.jpeg', '.png']

    # 디렉토리 순회
    for filename in os.listdir(directory):
        ext = os.path.splitext(filename)[1].lower()
        if ext in valid_extensions:
            input_path = os.path.join(directory, filename)
            output_path = os.path.splitext(input_path)[0] + ".webp"
            
            try:
                image = Image.open(input_path).convert("RGB")  # RGBA → RGB로 자동 변환
                image.save(output_path, "webp", quality=quality)
                print(f"✔ Converted: {filename} → {os.path.basename(output_path)}")
            except Exception as e:
                print(f"✘ Failed: {filename} ({e})")

# 🔧 사용 예시
#convert_all_images_to_webp("./main-page", quality=85)

# %%
import os
os.getcwd()
# Out:
# 'd:\\code\\kmaikms.github.io\\assets\\images'

# %%
convert_all_images_to_webp("./test", quality=85)
# Out:
# ✔ Converted: 증명사진_고윤영.jpg → 증명사진_고윤영.webp

# %%
convert_all_images_to_webp("./member/students", quality=85)
# Out:
# ✔ Converted: 증명사진_김지헌.png → 증명사진_김지헌.webp
# ✔ Converted: 증명사진_노원우.jpg → 증명사진_노원우.webp
# ✔ Converted: 증명사진_박선영.jpg → 증명사진_박선영.webp
# ✔ Converted: 증명사진_변영훈.png → 증명사진_변영훈.webp
# ✔ Converted: 증명사진_서예찬.png → 증명사진_서예찬.webp
# ✔ Converted: 증명사진_손진영.png → 증명사진_손진영.webp
# ✔ Converted: 증명사진_송주훈.jpg → 증명사진_송주훈.webp
# ✔ Converted: 증명사진_신종현.png → 증명사진_신종현.webp
# ✔ Converted: 증명사진_신현우.png → 증명사진_신현우.webp
# ✔ Converted: 증명사진_이건희.jpg → 증명사진_이건희.webp
# ✔ Converted: 증명사진_이관영.png → 증명사진_이관영.webp
# ✔ Converted: 증명사진_이재영.png → 증명사진_이재영.webp
# ✔ Converted: 증명사진_이종현.png → 증명사진_이종현.webp
# ✔ Converted: 증명사진_조수혜.jpg → 증명사진_조수혜.webp
# ✔ Converted: 증명사진_최진원.jpg → 증명사진_최진원.webp
# ✔ Converted: 증명사진_최호재.png → 증명사진_최호재.webp
# ✔ Converted: 증명사진_하승엽.png → 증명사진_하승엽.webp
# ✔ Converted: 증명사진_황재훈.png → 증명사진_황재훈.webp

# %%
convert_all_images_to_webp("./news", quality=85)
# Out:
# ✔ Converted: 2023_catheter.png → 2023_catheter.webp
# ✔ Converted: 2024_monthly.png → 2024_monthly.webp
# ✔ Converted: 2025_helloT.png → 2025_helloT.webp

# %%
convert_all_images_to_webp("./activities/2023", quality=85)
convert_all_images_to_webp("./activities/2024", quality=85)
convert_all_images_to_webp("./activities/2025", quality=85)
# Out:
# ✔ Converted: 2023_한국정보_우수논문_신우상.png → 2023_한국정보_우수논문_신우상.webp
# ✔ Converted: 2023_한국정보_우수논문_이태한.png → 2023_한국정보_우수논문_이태한.webp
# ✔ Converted: 2024 Canada-Korea Conference.jpg → 2024 Canada-Korea Conference.webp
# ✔ Converted: 2024 KITECH-GT MOU.jpg → 2024 KITECH-GT MOU.webp
# ✔ Converted: 2024 KITECH-TUD.jpg → 2024 KITECH-TUD.webp
# ✔ Converted: 2024 XR 디바이스 콘텐츠 메이커톤, 정보통신산업진흥원장상 수상.png → 2024 XR 디바이스 콘텐츠 메이커톤, 정보통신산업진흥원장상 수상.webp
# ✔ Converted: 2024 대구특구 출연연 사업화 유망기술.png → 2024 대구특구 출연연 사업화 유망기술.webp
# ✔ Converted: 2024 대한금속재료학회.jpg → 2024 대한금속재료학회.webp
# ✔ Converted: 2024 스마트 공장 자동화 산업전 전문가 초청 강연.png → 2024 스마트 공장 자동화 산업전 전문가 초청 강연.webp
# ✔ Converted: 2024 자율제조 월드 콩그레스 초청강연.png → 2024 자율제조 월드 콩그레스 초청강연.webp
# ✔ Converted: 2024 한국PHM학회 초청강연.jpg → 2024 한국PHM학회 초청강연.webp
# ✔ Converted: 2024 환경독성보건학회 추계학술대회, 포스터 구두 발표상 & 우수 포스터 상 수상.jpg → 2024 환경독성보건학회 추계학술대회, 포스터 구두 발표상 & 우수 포스터 상 수상.webp
# ✔ Converted: KIMS TECHFAIR, NextGenConnect.png → KIMS TECHFAIR, NextGenConnect.webp
# ✔ Converted: Miracom Solution Fair강연.jpg → Miracom Solution Fair강연.webp
# ✔ Converted: 대한금속재료학회 추계학술대회, 학생구두발표 우수상 수상.png → 대한금속재료학회 추계학술대회, 학생구두발표 우수상 수상.webp
# ✔ Converted: 대한임베디드공학회 ISET 2024, Tutorial 강연.png → 대한임베디드공학회 ISET 2024, Tutorial 강연.webp
# ✔ Converted: 대한임베디드공학회 ISET 2024.png → 대한임베디드공학회 ISET 2024.webp
# ✔ Converted: 대한임베디드공학회 추계학술대회, 우수논문발표상 수상.png → 대한임베디드공학회 추계학술대회, 우수논문발표상 수상.webp
# ✔ Converted: 대한임베디드공학회 추계학술대회, 우수논문발표상 수상_윤종필.png → 대한임베디드공학회 추계학술대회, 우수논문발표상 수상_윤종필.webp
# ✔ Converted: 대한임베디드공학회 추계학술대회, 우수논문상 수상_신우상.png → 대한임베디드공학회 추계학술대회, 우수논문상 수상_신우상.webp
# ✔ Converted: 대한임베디드공학회 추계학술대회, 우수논문상 수상_윤종필.png → 대한임베디드공학회 추계학술대회, 우수논문상 수상_윤종필.webp
# ✔ Converted: 인천테크노파크 AI 내재화.png → 인천테크노파크 AI 내재화.webp
# ✔ Converted: 2025_AMWS.png → 2025_AMWS.webp
# ✔ Converted: 2025_aw.png → 2025_aw.webp
# ✔ Converted: 2025_innotech.png → 2025_innotech.webp
# ✔ Converted: 2025_IRI.png → 2025_IRI.webp
# ✔ Converted: 2025_KEIT.png → 2025_KEIT.webp
# ✔ Converted: 2025_Keytech.jpg → 2025_Keytech.webp
# ✔ Converted: 2025_KICC.png → 2025_KICC.webp
# ✔ Converted: 2025_kofas.png → 2025_kofas.webp
# ✔ Converted: 2025_KoreaIndustrialAI.jpg → 2025_KoreaIndustrialAI.webp
# ✔ Converted: 2025_실용인공지능.png → 2025_실용인공지능.webp
# ✔ Converted: 2025_재료인공지능.png → 2025_재료인공지능.webp
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
